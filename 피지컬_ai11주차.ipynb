# %%
#외울 내용
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

x_train = np.array([
    [10,8,2],
    [5,6,5],
    [8,7,3],
    [2,5,8]
])
y_train = np.array([95,60,85,40])

model = keras.Sequential([
    layers.Dense(units=16, activation='relu', input_shape=(3,),
    name="Hidden_Layer_1"),

    layers.Dense(units=1, name="Output_Layer")
])
model.summary()

model.compile(optimizer='adam', loss='mse')
print("딥러닝 모델이 패턴을 학습합니다")
model.fit(x_train, y_train, epochs=100, verbose=0)

new_student = np.array([[7,7,4]])
prediction = model.predict(new_student)
print(f"이 학생의 예상 점수는: {prediction[0][0]:.1f}점 입니다.")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_Layer_1 (Dense)          │ (None, 16)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
# ...

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

x_train = np.array([
    [10,8,2],
    [5,6,5],
    [8,7,3],
    [2,5,8]
])
y_train = np.array([95,60,85,40])

model = keras.Sequential([
    layers.Dense(units=16, activation='relu', input_shape=(3,),
    name="Hidden_Layer_1"),
    layers.Dense(units=8, activation='relu', name="Hidden_Layer_2"),
    layers.Dense(units=1, name="Output_Layer")
])
model.summary()

model.compile(optimizer='adam', loss='mse')
print("딥러닝 모델이 패턴을 학습합니다")
model.fit(x_train, y_train, epochs=100, verbose=0)

new_student = np.array([[7,7,4]])
prediction = model.predict(new_student)
print(f"이 학생의 예상 점수는 : {prediction[0][0]:.1f}점 입니다.")
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_Layer_1 (Dense)          │ (None, 16)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_2 (Dense)          │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 209 (836.00 B)
#  Trainable params: 209 (836.00 B)
#  Non-trainable params: 0 (0.00 B)
# 딥러닝 모델이 패턴을 학습합니다
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이 학생의 예상 점수는 : 3.0점 입니다.

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

(train_images, train_labels), (test_images, test_labels)=tf.keras.datasets.mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
plt.imshow(train_images[0], cmap='gray')

# %%
from tensorflow.keras import layers
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(512, activation='relu', input_shape=(784,)))
model.add(tf.keras.layers.Dense(10, activation='sigmoid'))

# %%
train_images = train_images.reshape((60000,784))
train_images = train_images.astype('float32') / 255.0

test_images = test_images.reshape((10000,784))
test_images = test_images.astype('float32') / 255.0

# %%
train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# %%
# ✅ 수정 코드
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9227 - loss: 0.2691
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9682 - loss: 0.1103
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9793 - loss: 0.0711
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9855 - loss: 0.0507
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9891 - loss: 0.0373

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('테스트 정확도:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9794 - loss: 0.0685
# 테스트 정확도: 0.9793999791145325

# %%
history = model.fit(train_images, train_labels, epochs=5, batch_size=128)
loss = history.history['loss']
acc = history.history['accuracy']
epochs = range(1, len(loss)+1)

plt.plot(epochs, loss, 'b', label = 'Training Loss')
plt.plot(epochs, acc, 'r', label = 'Accuracy')
plt.xlabel('epochs')
plt.ylabel('loss/acc')
plt.show()
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9925 - loss: 0.0269
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9939 - loss: 0.0210
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9961 - loss: 0.0154
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9969 - loss: 0.0125
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9981 - loss: 0.0088
